# %%
from langchain_community.vectorstores import FAISS
from langchain_ollama import OllamaEmbeddings

# %%
from langchain_core.documents import Document
documents = [
    Document(page_content="LangChain helps developers build LLM applications easily."),
    Document(page_content="Chroma is a vector database optimized for LLM-based search."),
    Document(page_content="Embeddings convert text into high-dimensional vectors."),
    Document(page_content="OpenAI provides powerful embedding models."),
]

# %%
vector_store = FAISS.from_documents(
    embedding = OllamaEmbeddings(model = 'nomic-embed-text'),
    documents = documents,
)

# %%
retriever = vector_store.as_retriever(
    search_type = 'mmr',
    search_kwargs = {'k':2 , 'lambda_mult' : 0.5} # 0 for most diverse result
)

# %%
result = retriever.invoke('What is Langchain')
print(result)
# Out:
# [Document(id='3b4ab2f1-855b-4f3a-a1f1-74223c0473f3', metadata={}, page_content='Chroma is a vector database optimized for LLM-based search.'), Document(id='e746af7a-b2d2-4609-bf49-548b76ec5f9f', metadata={}, page_content='Embeddings convert text into high-dimensional vectors.')]

# %%
for i , doc in enumerate(result):
    print(doc.page_content)
# Out:
# Chroma is a vector database optimized for LLM-based search.
# Embeddings convert text into high-dimensional vectors.
